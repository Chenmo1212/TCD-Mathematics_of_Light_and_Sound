# %% [markdown]
# # Question Description

# %% [markdown]
# Write a program to plot images that show the difference between the probability density of the sum of two wave resultant intensities and the probability density of one wave resultant intensity.

# %% [markdown]
# ## Answer

# %%
# import the libs
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Different ${\lambda}$ will lead to different results, the specific formula is as follows:
#
# $$
# f_{Z}(z)=\left\{\begin{array}{ll}
# \frac{\lambda_{X} \lambda_{Y}}{\lambda_{Y}-\lambda_{X}}\left(\mathrm{e}^{-\lambda_{X} z}-\mathrm{e}^{-\lambda_{Y} z}\right) &\text { when } \lambda_{Y} \neq \lambda_{X} . \\
# z \lambda^{2} \mathrm{e}^{-\lambda z} & \text { when } \lambda=\lambda_{X}=\lambda_{Y}
# \end{array}\right.
# $$

# %%
def get_intensity(lambda_):
    return np.exp(-nums * lambda_) * lambda_


def get_sum_intensity(l1, l2):
    if l1 == l2:
        # f_z = z * λ^2 * exp(−λ * z)
        return nums * l1 ** 2 * np.exp(-nums * l1)
    else:
        # f_z = λX * λY / (λY − λX) * (exp(−z * λX) − exp(−z * λY))
        return (l2 * l1) / (l1 - l2) * (np.exp(-nums * l2) - np.exp(-nums * l1))

# %%
if __name__ == '__main__':
    nums = np.arange(0, 10, 0.1)

    fig = plt.figure(figsize=(10, 5))
    fig.suptitle('Probability density of the sum of the wave resultant intensities', fontsize=14)

    ax1 = fig.add_subplot(121)
    plt.plot(nums, get_intensity(1), label="I1")
    plt.plot(nums, get_intensity(2), label="I2")
    plt.plot(nums, get_sum_intensity(2, 1), label="I1+I2")
    plt.title("Result of λ1 != λ2")
    plt.legend()

    ax2 = fig.add_subplot(122)
    plt.plot(nums, get_intensity(1), label="I1&I2")
    plt.plot(nums, get_sum_intensity(1, 1), label="I1+I2")
    plt.title("Result of λ1 == λ2")
    plt.legend()

    plt.savefig('Q4_Probability_density_of_the_sum_of_the_wave_resultant_intensities')
    plt.show()
